# %%
from utils import get_meta
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import os
import cv2
# %matplotlib inline
from tqdm import tqdm

# %%
db='wiki'
mat_path='/home/geekysethi/Desktop/age-and-gender/age-and-gender/data/wiki_crop/wiki.mat'
full_path, dob, gender, photo_taken, face_score, second_face_score, age= get_meta(mat_path, db)

temp_dataframe={"full_path":full_path,'gender':gender,'face_score':face_score,'second_face_score':second_face_score,'age':age}
df=pd.DataFrame(temp_dataframe)
print(df.head())
train_dir='/home/geekysethi/Desktop/age-and-gender/age-and-gender/data/wiki_crop/'

img_size=50
LR=1e-3
model_name='ageandgender-{}-{}.model'.format(LR,'2conv_basic')
# Out:
#    age  face_score                          full_path  gender  \
# 0   28    4.300962  [17/10000217_1981-05-05_2009.jpg]     1.0
# 1   39    2.645639  [48/10000548_1925-04-04_1964.jpg]     1.0
# 2   59    4.329329    [12/100012_1948-07-03_2008.jpg]     1.0
# 3   31        -inf  [65/10001965_1930-05-23_1961.jpg]     1.0
# 4   41    3.408442  [16/10002116_1971-05-31_2012.jpg]     0.0
#
#    second_face_score
# 0                NaN
# 1           1.949248
# 2                NaN
# 3                NaN
# 4                NaN

# %%
path=[]
type(df.full_path)
for i in df.full_path:
    i=str(i)[2:-2]
    path.append(os.path.join(train_dir,str(i)))

# img=cv2.imread(path[0],0)
# im_size=img.shape[:2]
# print(im_size)

# %%
def show_images(path):
    fig=plt.figure()
    for num, img_no in enumerate(path[:12]):
        y=fig.add_subplot(3,4,num+1)
        img=cv2.imread(img_no,0)
        y.imshow(img,cmap='gray')
        y.axes.get_xaxis().set_visible(False)
        y.axes.get_yaxis().set_visible(False)

    
show_images(path)

# %%
img_paths=[]

for num, face_score in enumerate(df.face_score):
#     print(img_path)
    if face_score>1.0:
        img_paths.append(path[num])
print(len(path))
print(len(img_paths))
show_images(img_paths)
# Out:
# 62328
# 42993

# %%
img_paths=[]

for num, face_score in enumerate(df.face_score):
#     print(img_path)
    if 0.0<face_score<1.0:
        img_paths.append(path[num])
print(len(path))
print(len(img_paths))
show_images(img_paths)
# Out:
# 62328
# 1319

# %%
img_paths=[]

for num, face_score in enumerate(df.face_score):
#     print(img_path)
    if face_score<0.0:
        img_paths.append(path[num])
print(len(path))
print(len(img_paths))
show_images(img_paths)
# Out:
# 62328
# 18016

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.gender.isnull().sum()
# Out:
# 2643

# %%
df.drop(df[df.gender.isnull()==True].index,inplace=True)

# %%
df.gender.isnull().sum()
# Out:
# 0

# %%
len(df)
# Out:
# 59685

# %%
img_paths=[]
gender=[]

for num, face_score in enumerate(df.face_score):
#     print(img_path)
    if 0.0<face_score:
        img_paths.append(path[num])
        gender.append(df.gender)
print(len(path))
print(len(img_paths))
print(len(gender))

show_images(img_paths)
df.head()
# Out:
# 62328
# 43452
# 43452
#    age  face_score                          full_path  gender  \
# 0   28    4.300962  [17/10000217_1981-05-05_2009.jpg]     1.0
# 1   39    2.645639  [48/10000548_1925-04-04_1964.jpg]     1.0
# 2   59    4.329329    [12/100012_1948-07-03_2008.jpg]     1.0
# 3   31        -inf  [65/10001965_1930-05-23_1961.jpg]     1.0
# 4   41    3.408442  [16/10002116_1971-05-31_2012.jpg]     0.0
#
#    second_face_score
# 0                NaN
# 1           1.949248
# 2                NaN
# 3                NaN
# 4                NaN

# %%
# df.drop(df[df.face_score=='-inf'].index,inplace=True)

# %%
from random import shuffle # mixing up or currently ordered data that might lead our network astray in training.

def create_label(temp):
    if temp==1:return [1,0]
    elif temp==0:return [0,1]

# %%
# if gender id 1 one hot is [1,0]
# else [0,1]
def create_train_data():
    training_data=[]
    for i, img_path in enumerate(img_paths[:1000]):
        img=cv2.imread(img_path,cv2.IMREAD_GRAYSCALE)
        img=cv2.resize(img,(img_size,img_size))
        label=create_label(gender[i])
        training_data.append([np.array(img),np.array(label)])
    
    shuffle(training_data)
    np.save('train_data_age.npy', training_data)
    print("Training Done")
    return training_data

# def create_train_data():
#     training_data=[]
#     for img in tqdm(os.listdir(train_dir)):
#         label=label_img(img)
#         path=os.path.join(train_dir,img)
#         img=cv2.imread(path,cv2.IMREAD_GRAYSCALE)
#         img=cv2.resize(img,(im_size,im_size))
#         training_data.append([np.array(img),np.array(label)])
#     shuffle(training_data)
#     np.save('training_data_age.npy',training_data)
#     return training_data

# %%
train_data=create_train_data()
# Out:
# Training Done

# %%
if os.path.isfile('train_data.npy'):
    train_data=np.load('train_data.npy')
else:
    train_data=create_train_data()

# %%
# train = train_data[:-10000]
# test = train_data[-10000:]

# X = np.array([i[0] for i in train]).reshape(-1,img_size,img_size,1)


# # Y = [np.array(i[1]) for i in train]

# # print(Y)
# print(len(X))
# # Y=np.empty([len(X),2])
# Y=[]
# for i in train:
#     Y.append(i[1])
# print(train[0])
# # Y=np.array(Y)
# # Y.reshape([len(X),2])
# # print(np.shape(Y))
# # print(type(Y))

# #Y=np.vstack(Y)
# print(np.shape(X))
# print(np.shape(Y))
# print(Y[1])
# print(train[2][0])
train =train_data[:-25]
test=train_data[-25:]
# print(train_data[4546][0])

X=np.array([i[0] for i in train]).reshape(-1,img_size,img_size,1)
Y=[i[1] for i in train]
# print(Y)
test_x=np.array([i[0] for i in test]).reshape(-1,img_size,img_size,1)
test_y=[i[1] for i in test]
print(np.shape(Y))

type(Y)
# Out:
# (975,)
# list

# %%
from sklearn.cross_validation import train_test_split

type(gender)
gender=list(gender)
print(type(gender))
n_files=len(img_paths)
print(n_files)
print(len(gender))
# Out:
# <class 'list'>
# 43452
# 43452
# /home/geekysethi/.virtualenvs/cv/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
if os.path.isfile('training_data_age-and-gender.npy'):
    total_images=np.load('training_data_age-and-gender.npy')
else:
    total_images = np.zeros((n_files, img_size, img_size, 1))
    count=0
    for img_path in tqdm(img_paths):
        img=cv2.imread(img_path,cv2.IMREAD_GRAYSCALE)
        img=cv2.resize(img,(img_size,img_size))
        total_images[count]=np.array(img.reshape(-1,img_size,img_size,1))
        count+=1
    np.save('training_data_age-and-gender.npy',total_images)
# Out:
# 100%|██████████| 43452/43452 [09:28<00:00, 76.47it/s]

# %%
# print(len(total_images))
# print(len(gender))
# print(total_images)
X, X_test, Y, Y_test = train_test_split(total_images, gender, test_size=0.1, random_state=42)

# %%
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
np_utils.to_categorical(Y, nb_classes=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-469c70f20eff> in <module>()
# ----> 1 np_utils.to_categorical(Y, nb_classes=2)
#
# NameError: name 'Y' is not defined

# %%
print(len(Y))
# print(np.shape(Y))
from tflearn.data_utils import shuffle, to_categorical
Y = to_categorical(Y, 2)
Y_test = to_categorical(Y_test, 2)
# Out:
# 39106
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-00d381734a4a> in <module>()
#       2 # print(np.shape(Y))
#       3 from tflearn.data_utils import shuffle, to_categorical
# ----> 4 Y = to_categorical(Y, 2)
#       5 Y_test = to_categorical(Y_test, 2)
#
# ~/.virtualenvs/cv/lib/python3.5/site-packages/tflearn/data_utils.py in to_categorical(y, nb_classes)
#      40         nb_classes = np.max(y)+1
#      41     Y = np.zeros((len(y), nb_classes))
# ---> 42     Y[np.arange(len(y)),y] = 1.
#      43     return Y
#      44
#
# IndexError: shape mismatch: indexing arrays could not be broadcast together with shapes (39106,) (39106,59685)

# %%
print(np.shape(Y))
# Out:
# (950,)

# %%
import tflearn
from tflearn.layers.conv import conv_2d,max_pool_2d
from tflearn.layers.core import input_data,dropout,fully_connected
from tflearn.layers.estimator import regression

import tensorflow as tf
tf.reset_default_graph()

convnet=input_data(shape=[None,img_size,img_size,1],name='input')

convnet=conv_2d(convnet,32,5,activation='relu')
convnet=max_pool_2d(convnet,5)

convnet=conv_2d(convnet,64,5,activation='relu')
convnet=max_pool_2d(convnet,5)

convnet=fully_connected(convnet,1024,activation='relu')
convnet=dropout(convnet,0.8)

convnet=fully_connected(convnet,2,activation='softmax')
convnet=regression(convnet,optimizer='adam',learning_rate=LR,loss='categorical_crossentropy',name='targets')


model=tflearn.DNN(convnet,tensorboard_verbose=3)

if os.path.exists('{}.meta'.format(model_name)):
    model.load(model_name)
    print('model loaded!')
train =train_data[:-50]
test=train_data[-50:]

X=np.array([i[0] for i in train]).reshape(-1,img_size,img_size,1)
Y=[i[1] for i in train]

test_x=np.array([i[0] for i in test]).reshape(-1,img_size,img_size,1)
test_y=[i[1] for i in test]

model.fit({'input':X},{'targets':Y},n_epoch=5,validation_set=({'input':X_test},{'targets':Y_test}),
snapshot_step=500,show_metric=True,run_id=model_name)

model.save(model_name)
# Out:
# INFO:tensorflow:Restoring parameters from /home/geekysethi/Desktop/age-and-gender/age-and-gender/ageandgender-0.001-2conv_basic.model
# INFO:tensorflow:Restoring parameters from /home/geekysethi/Desktop/age-and-gender/age-and-gender/ageandgender-0.001-2conv_basic.model
# model loaded!
# ---------------------------------
# Run id: ageandgender-0.001-2conv_basic.model
# Log directory: /tmp/tflearn_logs/
# INFO:tensorflow:Summary name Accuracy/ (raw) is illegal; using Accuracy/__raw_ instead.
# INFO:tensorflow:Summary name Accuracy/ (raw) is illegal; using Accuracy/__raw_ instead.
# ---------------------------------
# Training samples: 950
# Validation samples: 4346
# --
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-379-f6344bc65c83> in <module>()
#      37
# ...
